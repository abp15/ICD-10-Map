# %% [markdown]
# ### This python code creates a graph for ICD-10 Codes
# #### Parent nodes are 3 character ICD-10 parent-codes (e.g. A00)
# #### Children nodes are parent-codes followed by decimal and digits (e.g. A00.12)
# #### Graph is saved in a ".pkl" file

# %%
import pandas as pd
from neo4j import GraphDatabase
import os
import sys

# %%
class Graph:
    def __init__(self):
        self.adjacency_list = {}
        self.node_data = {}

    def add_node(self, node, **kwargs):
        if node not in self.adjacency_list:
            self.adjacency_list[node] = []
        if kwargs:
            self.node_data[node] = kwargs

    def get_node_data(self, node):
        return self.node_data.get(node, {})

    def add_edge(self, node1, node2):
        if node1 not in self.adjacency_list:
            self.add_node(node1)
        if node2 not in self.adjacency_list:
            self.add_node(node2)
        
        self.adjacency_list[node1].append(node2)
        self.adjacency_list[node2].append(node1) # Undirected graph

    def add_directed_edge(self, from_node, to_node):
        if from_node not in self.adjacency_list:
            self.add_node(from_node)
        if to_node not in self.adjacency_list:
            self.add_node(to_node)
        
        self.adjacency_list[from_node].append(to_node)

    def get_neighbors(self, node):
        return self.adjacency_list.get(node, [])

    def __str__(self):
        return str(self.adjacency_list)

    def save_to_file(self, filename):
        # Save the graph to a file using pickle
        import pickle
        with open(filename, 'wb') as f:
            pickle.dump({'adjacency_list': self.adjacency_list, 
                        'node_data': self.node_data}, f)
        print(f"Graph saved to {filename}")
    
    @staticmethod
    def load_from_file(filename):
        # Load a graph from a file
        import pickle
        with open(filename, 'rb') as f:
            data = pickle.load(f)
        
        graph = Graph()
        graph.adjacency_list = data['adjacency_list']
        graph.node_data = data['node_data']
        print(f"Graph loaded from {filename}")
        return graph



def import_icd_from_csv_pandas(graph, csv_file):
    df = pd.read_csv(csv_file)
    
    # Ensure 'code' column exists
    if 'Code' not in df.columns:
        raise ValueError("CSV must have a 'Code' column")
    
    # Fill NaN descriptions
    if 'Description' in df.columns:
        df['Description'] = df['Description'].fillna('')

    df['Clean_Description'] = df['Code'] + '\n' + df['Description']
    
    # First pass: Add all nodes with attributes
    for _, row in df.iterrows():
        code = str(row['Code'])
        description = str(row.get('Clean_Description', ''))
        graph.add_node(code, description=description)
        
    # Second pass: Build relationships
    codes = df['Code'].astype(str).tolist()
    for code in codes:
        if '.' in code:
            # It's a child node (has decimal)
            # Find the parent (first 3 characters)
            parent = code.split('.')[0]
            
            # Only add edge if parent exists in our list
            # 3-char codes are parents
            if len(parent) == 3:
                graph.add_directed_edge(parent, code)

# %%
#### USe icd_codes.csv to build hirarchical graphs

# %%
# ICD-10 Example
icd_graph = Graph()
import_icd_from_csv_pandas(icd_graph, 'icd_codes.csv')

print("ICD Graph Structure (Parents with Children):")
for node in icd_graph.adjacency_list:
    # Only print nodes that are parents (length 3) and have children
    if len(node) == 3:
        children = icd_graph.get_neighbors(node)
        if children:
            parent_desc = icd_graph.get_node_data(node).get('description', '')
            print(f"{node} ({parent_desc}) ->")
            for child in children:
                child_desc = icd_graph.get_node_data(child).get('description', '')
                print(f"  - {child} ({child_desc})")
# Out:
# ICD Graph Structure (Parents with Children):
# A19 (A19
# O98.01 ) ->
#   - A19.0 (A19.0
# Acute miliary tuberculosis of a single specified site )
#   - A19.1 (A19.1
# Acute miliary tuberculosis of multiple sites )
#   - A19.2 (A19.2
# Acute miliary tuberculosis, unspecified )
#   - A19.8 (A19.8
# Other miliary tuberculosis )
#   - A19.9 (A19.9
# Miliary tuberculosis, unspecified )
# A28 (A28
# Other zoonotic bacterial diseases, not elsewhere classified ) ->
#   - A28.0 (A28.0
# Pasteurellosis )
#   - A28.1 (A28.1
# Cat-scratch disease )
#   - A28.2 (A28.2
# Extraintestinal yersiniosis )
#   - A28.8 (A28.8
# Other specified zoonotic bacterial diseases, not elsewhere )
#   - A28.9 (A28.9
# Zoonotic bacterial disease, unspecified  )
# A49 (A49
# Bacterial infection of unspecified site ) ->
#   - A49.0 (A49.0
# Staphylococcal infection, unspecified site )
#   - A49.1 (A49.1
# Streptococcal infection, unspecified site )
#   - A49.2 (A49.2
# Hemophilus influenzae infection, unspecified site )
#   - A49.3 (A49.3
# Mycoplasma infection, unspecified site )
#   - A49.8 (A49.8
# Other bacterial infections of unspecified site )
#   - A49.9 (A49.9
# Bacterial infection, unspecified )
# A69 (A69
# Other spirochetal infections ) ->
#   - A69.0 (A69.0
# Necrotizing ulcerative stomatitis )
#   - A69.1 (A69.1
# Other Vincent's infections )
#   - A69.2 (A69.2
# Lyme disease )
#   - A69.20 (A69.20
# Lyme disease, unspecified )
#   - A69.21 (A69.21
# Meningitis due to Lyme disease )
#   - A69.22 (A69.22
# Other neurologic disorders in Lyme disease )
#   - A69.23 (A69.23
# Arthritis due to Lyme disease )
#   - A69.29 (A69.29
# Other conditions associated with Lyme disease )
#   - A69.8 (A69.8
# Other specified spirochetal infections )
#   - A69.9 (A69.9
# Spirochetal infection, unspecified )
# A74 (A74
# Other diseases caused by chlamydiae ) ->
#   - A74.0 (A74.0
# Chlamydial conjunctivitis  )
#   - A74.8 (A74.8
# Other chlamydial diseases )
#   - A74.81 (A74.81
# Chlamydial peritonitis )
#   - A74.89 (A74.89
# Other chlamydial diseases )
#   - A74.9 (A74.9
# Chlamydial infection, unspecified )
# A79 (A79
# Other rickettsioses ) ->
#   - A79.0 (A79.0
# Trench fever )
#   - A79.1 (A79.1
# Rickettsialpox due to Rickettsia akari )
#   - A79.8 (A79.8
# Other specified rickettsioses )
#   - A79.81 (A79.81
# Rickettsiosis due to Ehrlichia sennetsu )
#   - A79.89 (A79.89
# Other specified rickettsioses )
#   - A79.9 (A79.9
# Rickettsiosis, unspecified )
# B10 (B10
# Other human herpesviruses ) ->
#   - B10.0 (B10.0
# Other human herpesvirus encephalitis )
#   - B10.01 (B10.01
# Human herpesvirus 6 encephalitis )
#   - B10.09 (B10.09
# Other human herpesvirus encephalitis )
#   - B10.8 (B10.8
# Other human herpesvirus infection )
#   - B10.81 (B10.81
# Human herpesvirus 6 infection )
#   - B10.82 (B10.82
# Human herpesvirus 7 infection )
#   - B10.89 (B10.89
# Other human herpesvirus infection )
# B19 (B19
# O98.41 ) ->
#   - B19.0 (B19.0
# Unspecified viral hepatitis with hepatic coma )
#   - B19.1 (B19.1
# Unspecified viral hepatitis B )
#   - B19.10 (B19.10
# Unspecified viral hepatitis B without hepatic coma )
#   - B19.11 (B19.11
# Unspecified viral hepatitis B with hepatic coma )
#   - B19.2 (B19.2
# Unspecified viral hepatitis C )
#   - B19.20 (B19.20
# Unspecified viral hepatitis C without hepatic coma )
#   - B19.21 (B19.21
# Unspecified viral hepatitis C with hepatic coma )
#   - B19.9 (B19.9
# Unspecified viral hepatitis without hepatic coma )
# B34 (B34
# Viral infection of unspecified site ) ->
#   - B34.0 (B34.0
# Adenovirus infection, unspecified )
#   - B34.1 (B34.1
# Enterovirus infection, unspecified )
#   - B34.2 (B34.2
# Coronavirus infection, unspecified )
#   - B34.3 (B34.3
# Parvovirus infection, unspecified )
#   - B34.4 (B34.4
# Papovavirus infection, unspecified )
#   - B34.8 (B34.8
# Other viral infections of unspecified site )
#   - B34.9 (B34.9
# Viral infection, unspecified )
# B83 (B83
# Other helminthiases ) ->
#   - B83.0 (B83.0
# Visceral larva migrans )
#   - B83.1 (B83.1
# Gnathostomiasis )
#   - B83.2 (B83.2
# Angiostrongyliasis due to Parastrongylus cantonensis )
#   - B83.3 (B83.3
# Syngamiasis )
#   - B83.4 (B83.4
# Internal hirudiniasis )
#   - B83.8 (B83.8
# Other specified helminthiases )
#   - B83.9 (B83.9
# Helminthiasis, unspecified )
# B94 (B94
# Poisoning by other viral vaccines, undetermined ) ->
#   - B94.0 (B94.0
# Sequelae of trachoma )
#   - B94.1 (B94.1
# Sequelae of viral encephalitis )
#   - B94.2 (B94.2
# Sequelae of viral hepatitis )
#   - B94.8 (B94.8
# Sequelae of other specified infectious and parasitic diseases )
#   - B94.9 (B94.9
# Sequelae of unspecified infectious and parasitic disease )
# B97 (B97
# Viral agents as the cause of diseases classified elsewhere ) ->
#   - B97.0 (B97.0
# Adenovirus as the cause of diseases classified elsewhere )
#   - B97.1 (B97.1
# Enterovirus as the cause of diseases classified elsewhere )
#   - B97.10 (B97.10
# Unspecified enterovirus as the cause of diseases )
#   - B97.11 (B97.11
# Coxsackievirus as the cause of diseases classified )
#   - B97.12 (B97.12
# Echovirus as the cause of diseases classified )
#   - B97.19 (B97.19
# Other enterovirus as the cause of diseases classified )
#   - B97.2 (B97.2
# Coronavirus as the cause of diseases classified elsewhere )
#   - B97.21 (B97.21
# SARS-associated coronavirus as the cause of )
#   - B97.29 (B97.29
# Other coronavirus as the cause of diseases classified )
#   - B97.3 (B97.3
# Retrovirus as the cause of diseases classified elsewhere )
#   - B97.30 (B97.30
# Unspecified retrovirus as the cause of diseases )
#   - B97.31 (B97.31
# Lentivirus as the cause of diseases classified )
#   - B97.32 (B97.32
# Oncovirus as the cause of diseases classified )
#   - B97.33 (B97.33
# Human T-cell lymphotrophic virus, type I [HTLV-I] as )
#   - B97.34 (B97.34
# Human T-cell lymphotrophic virus, type II [HTLV-II] as )
#   - B97.35 (B97.35
# Human immunodeficiency virus, type 2 [HIV 2] as the )
#   - B97.39 (B97.39
# Other retrovirus as the cause of diseases classified )
#   - B97.4 (B97.4
# Respiratory syncytial virus as the cause of diseases classified )
#   - B97.5 (B97.5
# Reovirus as the cause of diseases classified elsewhere )
#   - B97.6 (B97.6
# Parvovirus as the cause of diseases classified elsewhere )
#   - B97.7 (B97.7
# Papillomavirus as the cause of diseases classified elsewhere )
#   - B97.8 (B97.8
# Other viral agents as the cause of diseases classified )
#   - B97.81 (B97.81
# Human metapneumovirus as the cause of diseases )
#   - B97.89 (B97.89
# Other viral agents as the cause of diseases classified )
# B99 (B99
# Excludes1: personal history of infectious diseases specific to a body ) ->
#   - B99.8 (B99.8
# Other infectious disease )
#   - B99.9 (B99.9
# Unspecified infectious disease )
# A00 (A00
# Cholera  ) ->
#   - A00.0 (A00.0
# Cholera due to Vibrio cholerae 01, biovar cholerae )
#   - A00.1 (A00.1
# Cholera due to Vibrio cholerae 01, biovar eltor )
#   - A00.9 (A00.9
# Cholera, unspecified )
# A01 (A01
# Typhoid and paratyphoid fevers ) ->
#   - A01.0 (A01.0
# Typhoid fever )
#   - A01.00 (A01.00
# Typhoid fever, unspecified )
#   - A01.01 (A01.01
# Typhoid meningitis )
#   - A01.02 (A01.02
# Typhoid fever with heart involvement )
#   - A01.03 (A01.03
# Typhoid pneumonia )
#   - A01.04 (A01.04
# Typhoid arthritis )
#   - A01.05 (A01.05
# Typhoid osteomyelitis )
#   - A01.09 (A01.09
# Typhoid fever with other complications )
#   - A01.1 (A01.1
# Paratyphoid fever A )
#   - A01.2 (A01.2
# Paratyphoid fever B )
#   - A01.3 (A01.3
# Paratyphoid fever C  )
#   - A01.4 (A01.4
# Paratyphoid fever, unspecified )
# A02 (A02
# Other salmonella infections ) ->
#   - A02.0 (A02.0
# Salmonella enteritis )
#   - A02.1 (A02.1
# Salmonella sepsis )
#   - A02.2 (A02.2
# Localized salmonella infections )
#   - A02.20 (A02.20
# Localized salmonella infection, unspecified )
#   - A02.21 (A02.21
# Salmonella meningitis )
#   - A02.22 (A02.22
# Salmonella pneumonia )
#   - A02.23 (A02.23
# Salmonella arthritis )
#   - A02.24 (A02.24
# Salmonella osteomyelitis )
#   - A02.25 (A02.25
# Salmonella pyelonephritis )
#   - A02.29 (A02.29
# Salmonella with other localized infection )
#   - A02.8 (A02.8
# Other specified salmonella infections )
#   - A02.9 (A02.9
# Salmonella infection, unspecified )
# A03 (A03
# Shigellosis ) ->
#   - A03.0 (A03.0
# Shigellosis due to Shigella dysenteriae )
#   - A03.1 (A03.1
# Shigellosis due to Shigella flexneri )
#   - A03.2 (A03.2
# Shigellosis due to Shigella boydii )
#   - A03.3 (A03.3
# Shigellosis due to Shigella sonnei )
#   - A03.8 (A03.8
# Other shigellosis )
#   - A03.9 (A03.9
# Shigellosis, unspecified )
# A04 (A04
# Other bacterial intestinal infections ) ->
#   - A04.0 (A04.0
# Enteropathogenic Escherichia coli infection )
#   - A04.1 (A04.1
# Enterotoxigenic Escherichia coli infection )
#   - A04.2 (A04.2
# Enteroinvasive Escherichia coli infection )
#   - A04.3 (A04.3
# Enterohemorrhagic Escherichia coli infection )
#   - A04.4 (A04.4
# Other intestinal Escherichia coli infections )
#   - A04.5 (A04.5
# Campylobacter enteritis )
#   - A04.6 (A04.6
# Enteritis due to Yersinia enterocolitica )
#   - A04.7 (A04.7
# listeriosis (A32.-) )
#   - A04.8 (A04.8
# Other specified bacterial intestinal infections )
#   - A04.9 (A04.9
# Bacterial intestinal infection, unspecified )
#   - A04.7 (A04.7
# listeriosis (A32.-) )
# A05 (A05
# Other bacterial foodborne intoxications, not elsewhere ) ->
#   - A05.0 (A05.0
# Foodborne staphylococcal intoxication )
#   - A05.1 (A05.1
# Botulism food poisoning )
#   - A05.2 (A05.2
# Foodborne Clostridium perfringens [Clostridium welchii] )
#   - A05.3 (A05.3
# Foodborne Vibrio parahaemolyticus intoxication )
#   - A05.4 (A05.4
# Foodborne Bacillus cereus intoxication )
#   - A05.5 (A05.5
# Foodborne Vibrio vulnificus intoxication )
#   - A05.8 (A05.8
# Other specified bacterial foodborne intoxications )
#   - A05.9 (A05.9
# Bacterial foodborne intoxication, unspecified )
# A06 (A06
# Amebiasis ) ->
#   - A06.0 (A06.0
# Acute amebic dysentery )
#   - A06.1 (A06.1
# Chronic intestinal amebiasis )
#   - A06.2 (A06.2
# Amebic nondysenteric colitis )
#   - A06.3 (A06.3
# Ameboma of intestine )
#   - A06.4 (A06.4
# Amebic liver abscess )
#   - A06.5 (A06.5
# Amebic lung abscess  )
#   - A06.6 (A06.6
# Amebic brain abscess  )
#   - A06.7 (A06.7
# Cutaneous amebiasis )
#   - A06.8 (A06.8
# Amebic infection of other sites )
#   - A06.81 (A06.81
# Amebic cystitis )
#   - A06.82 (A06.82
# Other amebic genitourinary infections )
#   - A06.89 (A06.89
# Other amebic infections )
#   - A06.9 (A06.9
# Amebiasis, unspecified  )
# A07 (A07
# Other protozoal intestinal diseases ) ->
#   - A07.0 (A07.0
# Balantidiasis )
#   - A07.1 (A07.1
# Giardiasis [lambliasis] )
#   - A07.2 (A07.2
# Cryptosporidiosis )
#   - A07.3 (A07.3
# Isosporiasis )
#   - A07.4 (A07.4
# Cyclosporiasis )
#   - A07.8 (A07.8
# Other specified protozoal intestinal diseases )
#   - A07.9 (A07.9
# Protozoal intestinal disease, unspecified )
# A08 (A08
# Viral and other specified intestinal infections ) ->
#   - A08.0 (A08.0
# Rotaviral enteritis )
#   - A08.1 (A08.1
# Acute gastroenteropathy due to Norwalk agent and other small )
#   - A08.11 (A08.11
# Acute gastroenteropathy due to Norwalk agent )
#   - A08.19 (A08.19
# Acute gastroenteropathy due to other small round viruses )
#   - A08.2 (A08.2
# Adenoviral enteritis )
#   - A08.3 (A08.3
# Other viral enteritis )
#   - A08.31 (A08.31
# Calicivirus enteritis )
#   - A08.32 (A08.32
# Astrovirus enteritis )
#   - A08.39 (A08.39
# Other viral enteritis )
#   - A08.4 (A08.4
# Viral intestinal infection, unspecified )
#   - A08.8 (A08.8
# Other specified intestinal infections )
# A15 (A15
# Adverse effect of pertussis vaccine, including ) ->
#   - A15.0 (A15.0
# Tuberculosis of lung )
#   - A15.4 (A15.4
# Tuberculosis of intrathoracic lymph nodes )
#   - A15.5 (A15.5
# Tuberculosis of larynx, trachea and bronchus )
#   - A15.6 (A15.6
# Tuberculous pleurisy )
#   - A15.7 (A15.7
# Primary respiratory tuberculosis )
#   - A15.8 (A15.8
# Other respiratory tuberculosis )
#   - A15.9 (A15.9
# Respiratory tuberculosis unspecified )
# A17 (A17
# Tuberculosis of nervous system ) ->
#   - A17.0 (A17.0
# Tuberculous meningitis  )
#   - A17.1 (A17.1
# Meningeal tuberculoma  )
#   - A17.8 (A17.8
# Other tuberculosis of nervous system )
#   - A17.81 (A17.81
# Tuberculoma of brain and spinal cord )
#   - A17.82 (A17.82
# Tuberculous meningoencephalitis )
#   - A17.83 (A17.83
# Tuberculous neuritis )
#   - A17.89 (A17.89
# Other tuberculosis of nervous system )
#   - A17.9 (A17.9
# Tuberculosis of nervous system, unspecified )
# A18 (A18
# Tuberculosis of other organs ) ->
#   - A18.0 (A18.0
# Tuberculosis of bones and joints )
#   - A18.01 (A18.01
# Tuberculosis of spine )
#   - A18.02 (A18.02
# Tuberculous arthritis of other joints )
#   - A18.03 (A18.03
# Tuberculosis of other bones )
#   - A18.09 (A18.09
# Other musculoskeletal tuberculosis )
#   - A18.1 (A18.1
# Tuberculosis of genitourinary system )
#   - A18.10 (A18.10
# Tuberculosis of genitourinary system, unspecified )
#   - A18.11 (A18.11
# Tuberculosis of kidney and ureter )
#   - A18.12 (A18.12
# Tuberculosis of bladder )
#   - A18.13 (A18.13
# Tuberculosis of other urinary organs )
#   - A18.14 (A18.14
# Tuberculosis of prostate )
#   - A18.15 (A18.15
# Tuberculosis of other male genital organs )
#   - A18.16 (A18.16
# Tuberculosis of cervix )
#   - A18.17 (A18.17
# Tuberculous female pelvic inflammatory disease )
#   - A18.18 (A18.18
# Tuberculosis of other female genital organs )
#   - A18.2 (A18.2
# Tuberculous peripheral lymphadenopathy )
#   - A18.3 (A18.3
# Tuberculosis of intestines, peritoneum and mesenteric glands )
#   - A18.31 (A18.31
# Tuberculous peritonitis )
#   - A18.32 (A18.32
# Tuberculous enteritis )
#   - A18.39 (A18.39
# Retroperitoneal tuberculosis )
#   - A18.4 (A18.4
# Tuberculosis of skin and subcutaneous tissue )
#   - A18.5 (A18.5
# Tuberculosis of eye )
#   - A18.50 (A18.50
# Tuberculosis of eye, unspecified )
#   - A18.51 (A18.51
# Tuberculous episcleritis )
#   - A18.52 (A18.52
# Tuberculous keratitis )
#   - A18.53 (A18.53
# Tuberculous chorioretinitis )
#   - A18.54 (A18.54
# Tuberculous iridocyclitis )
#   - A18.59 (A18.59
# Other tuberculosis of eye )
#   - A18.6 (A18.6
# Tuberculosis of (inner) (middle) ear )
#   - A18.7 (A18.7
# Tuberculosis of adrenal glands  )
#   - A18.8 (A18.8
# Tuberculosis of other specified organs )
#   - A18.81 (A18.81
# Tuberculosis of thyroid gland )
#   - A18.82 (A18.82
# Tuberculosis of other endocrine glands )
#   - A18.83 (A18.83
# Tuberculosis of digestive tract organs, not elsewhere )
#   - A18.84 (A18.84
# Tuberculosis of heart )
#   - A18.85 (A18.85
# Tuberculosis of spleen )
#   - A18.89 (A18.89
# Tuberculosis of other sites )
# A20 (A20
# Plague ) ->
#   - A20.0 (A20.0
# Bubonic plague )
#   - A20.1 (A20.1
# Cellulocutaneous plague )
#   - A20.2 (A20.2
# Pneumonic plague )
#   - A20.3 (A20.3
# Plague meningitis )
#   - A20.7 (A20.7
# Septicemic plague )
#   - A20.8 (A20.8
# Other forms of plague )
#   - A20.9 (A20.9
# Plague, unspecified )
# A21 (A21
# Poisoning by mixed bacterial vaccines without a ) ->
#   - A21.0 (A21.0
# Ulceroglandular tularemia )
#   - A21.1 (A21.1
# Oculoglandular tularemia )
#   - A21.2 (A21.2
# Pulmonary tularemia )
#   - A21.3 (A21.3
# Gastrointestinal tularemia )
#   - A21.7 (A21.7
# Generalized tularemia )
#   - A21.8 (A21.8
# Other forms of tularemia )
#   - A21.9 (A21.9
# Tularemia, unspecified )
# A22 (A22
# Poisoning by mixed bacterial vaccines without a ) ->
#   - A22.0 (A22.0
# Cutaneous anthrax )
#   - A22.1 (A22.1
# Pulmonary anthrax )
#   - A22.2 (A22.2
# Gastrointestinal anthrax )
#   - A22.7 (A22.7
# Anthrax sepsis )
#   - A22.8 (A22.8
# Other forms of anthrax )
#   - A22.9 (A22.9
# Anthrax, unspecified )
# A23 (A23
# Poisoning by mixed bacterial vaccines without a ) ->
#   - A23.0 (A23.0
# Brucellosis due to Brucella melitensis )
#   - A23.1 (A23.1
# Brucellosis due to Brucella abortus )
#   - A23.2 (A23.2
# Brucellosis due to Brucella suis )
#   - A23.3 (A23.3
# Brucellosis due to Brucella canis )
#   - A23.8 (A23.8
# Other brucellosis )
#   - A23.9 (A23.9
# Brucellosis, unspecified )
# A24 (A24
# Poisoning by mixed bacterial vaccines without a ) ->
#   - A24.0 (A24.0
# Glanders )
#   - A24.1 (A24.1
# Acute and fulminating melioidosis )
#   - A24.2 (A24.2
# Subacute and chronic melioidosis )
#   - A24.3 (A24.3
# Other melioidosis )
#   - A24.9 (A24.9
# Melioidosis, unspecified )
# A25 (A25
# Adverse effect of mixed bacterial vaccines ) ->
#   - A25.0 (A25.0
# Spirillosis )
#   - A25.1 (A25.1
# Streptobacillosis )
#   - A25.9 (A25.9
# Rat-bite fever, unspecified )
# A26 (A26
# Underdosing of mixed bacterial vaccines without ) ->
#   - A26.0 (A26.0
# Cutaneous erysipeloid )
#   - A26.7 (A26.7
# Erysipelothrix sepsis )
#   - A26.8 (A26.8
# Other forms of erysipeloid  )
#   - A26.9 (A26.9
# Erysipeloid, unspecified  )
# A27 (A27
# Leptospirosis ) ->
#   - A27.0 (A27.0
# Leptospirosis icterohemorrhagica  )
#   - A27.8 (A27.8
# Other forms of leptospirosis  )
#   - A27.81 (A27.81
# Aseptic meningitis in leptospirosis )
#   - A27.89 (A27.89
# Other forms of leptospirosis )
#   - A27.9 (A27.9
# Leptospirosis, unspecified  )
# A30 (A30
# Leprosy [Hansen's disease] ) ->
#   - A30.0 (A30.0
# Indeterminate leprosy )
#   - A30.1 (A30.1
# Tuberculoid leprosy )
#   - A30.2 (A30.2
# Borderline tuberculoid leprosy )
#   - A30.3 (A30.3
# Borderline leprosy )
#   - A30.4 (A30.4
# Borderline lepromatous leprosy )
#   - A30.5 (A30.5
# Lepromatous leprosy )
#   - A30.8 (A30.8
# Other forms of leprosy )
#   - A30.9 (A30.9
# Leprosy, unspecified )
# A31 (A31
# Infection due to other mycobacteria ) ->
#   - A31.0 (A31.0
# Pulmonary mycobacterial infection )
#   - A31.1 (A31.1
# Cutaneous mycobacterial infection )
#   - A31.2 (A31.2
# Disseminated mycobacterium avium-intracellulare complex )
#   - A31.8 (A31.8
# Other mycobacterial infections )
#   - A31.9 (A31.9
# Mycobacterial infection, unspecified )
# A32 (A32
# Listeriosis ) ->
#   - A32.0 (A32.0
# Cutaneous listeriosis )
#   - A32.1 (A32.1
# Listerial meningitis and meningoencephalitis )
#   - A32.11 (A32.11
# Listerial meningitis )
#   - A32.12 (A32.12
# Listerial meningoencephalitis )
#   - A32.7 (A32.7
# Listerial sepsis )
#   - A32.8 (A32.8
# Other forms of listeriosis  )
#   - A32.81 (A32.81
# Oculoglandular listeriosis )
#   - A32.82 (A32.82
# Listerial endocarditis )
#   - A32.89 (A32.89
# Other forms of listeriosis )
#   - A32.9 (A32.9
# Listeriosis, unspecified )
# A36 (A36
# Diphtheria ) ->
#   - A36.0 (A36.0
# Pharyngeal diphtheria )
#   - A36.1 (A36.1
# Nasopharyngeal diphtheria )
#   - A36.2 (A36.2
# Laryngeal diphtheria )
#   - A36.3 (A36.3
# Cutaneous diphtheria )
#   - A36.8 (A36.8
# Other diphtheria )
#   - A36.81 (A36.81
# Diphtheritic cardiomyopathy )
#   - A36.82 (A36.82
# Diphtheritic radiculomyelitis )
#   - A36.83 (A36.83
# Diphtheritic polyneuritis )
#   - A36.84 (A36.84
# Diphtheritic tubulo-interstitial nephropathy )
#   - A36.85 (A36.85
# Diphtheritic cystitis )
#   - A36.86 (A36.86
# Diphtheritic conjunctivitis )
#   - A36.89 (A36.89
# Other diphtheritic complications )
#   - A36.9 (A36.9
# Diphtheria, unspecified )
# A37 (A37
# Whooping cough ) ->
#   - A37.0 (A37.0
# Whooping cough due to Bordetella pertussis )
#   - A37.00 (A37.00
# Whooping cough due to Bordetella pertussis without )
#   - A37.01 (A37.01
# Whooping cough due to Bordetella pertussis with )
#   - A37.1 (A37.1
# Whooping cough due to Bordetella parapertussis )
#   - A37.10 (A37.10
# Whooping cough due to Bordetella parapertussis )
#   - A37.11 (A37.11
# Whooping cough due to Bordetella parapertussis with )
#   - A37.8 (A37.8
# Whooping cough due to other Bordetella species )
#   - A37.80 (A37.80
# Whooping cough due to other Bordetella species )
#   - A37.81 (A37.81
# Whooping cough due to other Bordetella species with )
#   - A37.9 (A37.9
# Whooping cough, unspecified species )
#   - A37.90 (A37.90
# Whooping cough, unspecified species without )
#   - A37.91 (A37.91
# Whooping cough, unspecified species with pneumonia )
# A38 (A38
# Scarlet fever ) ->
#   - A38.0 (A38.0
# Scarlet fever with otitis media )
#   - A38.1 (A38.1
# Scarlet fever with myocarditis )
#   - A38.8 (A38.8
# Scarlet fever with other complications )
#   - A38.9 (A38.9
# Scarlet fever, uncomplicated )
# A39 (A39
# Meningococcal infection ) ->
#   - A39.0 (A39.0
# Meningococcal meningitis )
#   - A39.1 (A39.1
# Waterhouse-Friderichsen syndrome  )
#   - A39.2 (A39.2
# Acute meningococcemia )
#   - A39.3 (A39.3
# Chronic meningococcemia )
#   - A39.4 (A39.4
# Meningococcemia, unspecified )
#   - A39.5 (A39.5
# Meningococcal heart disease )
#   - A39.50 (A39.50
# Meningococcal carditis, unspecified )
#   - A39.51 (A39.51
# Meningococcal endocarditis )
#   - A39.52 (A39.52
# Meningococcal myocarditis )
#   - A39.53 (A39.53
# Meningococcal pericarditis )
#   - A39.8 (A39.8
# Other meningococcal infections )
#   - A39.81 (A39.81
# Meningococcal encephalitis )
#   - A39.82 (A39.82
# Meningococcal retrobulbar neuritis )
#   - A39.83 (A39.83
# Meningococcal arthritis )
#   - A39.84 (A39.84
# Postmeningococcal arthritis )
#   - A39.89 (A39.89
# Other meningococcal infections )
#   - A39.9 (A39.9
# Meningococcal infection, unspecified )
# A40 (A40
# Streptococcal sepsis ) ->
#   - A40.0 (A40.0
# Sepsis due to streptococcus, group A )
#   - A40.1 (A40.1
# Sepsis due to streptococcus, group B )
#   - A40.3 (A40.3
# Sepsis due to Streptococcus pneumoniae )
#   - A40.8 (A40.8
# Other streptococcal sepsis )
#   - A40.9 (A40.9
# Streptococcal sepsis, unspecified  )
# A41 (A41
# Other sepsis ) ->
#   - A41.0 (A41.0
# Sepsis due to Staphylococcus aureus )
#   - A41.1 (A41.1
# Sepsis due to other specified staphylococcus )
#   - A41.2 (A41.2
# Sepsis due to unspecified staphylococcus )
#   - A41.3 (A41.3
# Sepsis due to Hemophilus influenzae )
#   - A41.4 (A41.4
# Sepsis due to anaerobes )
#   - A41.5 (A41.5
# Sepsis due to other Gram-negative organisms )
#   - A41.50 (A41.50
# Gram-negative sepsis, unspecified )
#   - A41.51 (A41.51
# Sepsis due to Escherichia coli [E. coli] )
#   - A41.52 (A41.52
# Sepsis due to Pseudomonas )
#   - A41.53 (A41.53
# Sepsis due to Serratia )
#   - A41.59 (A41.59
# Other Gram-negative sepsis )
#   - A41.8 (A41.8
# Other specified sepsis )
#   - A41.81 (A41.81
# Sepsis due to Enterococcus )
#   - A41.89 (A41.89
# Other specified sepsis )
#   - A41.9 (A41.9
# Use additional code to identify specific acute organ )
#   - A41.9 (A41.9
# Use additional code to identify specific acute organ )
# A42 (A42
# Actinomycosis ) ->
#   - A42.0 (A42.0
# Pulmonary actinomycosis )
#   - A42.1 (A42.1
# Abdominal actinomycosis )
#   - A42.2 (A42.2
# Cervicofacial actinomycosis )
#   - A42.7 (A42.7
# Actinomycotic sepsis )
#   - A42.8 (A42.8
# Other forms of actinomycosis )
#   - A42.81 (A42.81
# Actinomycotic meningitis )
#   - A42.82 (A42.82
# Actinomycotic encephalitis )
#   - A42.89 (A42.89
# Other forms of actinomycosis )
#   - A42.9 (A42.9
# Actinomycosis, unspecified )
# A43 (A43
# Nocardiosis ) ->
#   - A43.0 (A43.0
# Pulmonary nocardiosis )
#   - A43.1 (A43.1
# Cutaneous nocardiosis )
#   - A43.8 (A43.8
# Other forms of nocardiosis )
#   - A43.9 (A43.9
# Nocardiosis, unspecified )
# A44 (A44
# Bartonellosis ) ->
#   - A44.0 (A44.0
# Systemic bartonellosis  )
#   - A44.1 (A44.1
# Cutaneous and mucocutaneous bartonellosis )
#   - A44.8 (A44.8
# Other forms of bartonellosis )
#   - A44.9 (A44.9
# Bartonellosis, unspecified  )
# A48 (A48
# Other bacterial diseases, not elsewhere classified ) ->
#   - A48.0 (A48.0
# Gas gangrene  )
#   - A48.1 (A48.1
# Legionnaires' disease )
#   - A48.2 (A48.2
# Nonpneumonic Legionnaires' disease [Pontiac fever] )
#   - A48.3 (A48.3
# Toxic shock syndrome )
#   - A48.4 (A48.4
# Brazilian purpuric fever )
#   - A48.5 (A48.5
# Other specified botulism )
#   - A48.51 (A48.51
# Infant botulism )
#   - A48.52 (A48.52
# Wound botulism )
#   - A48.8 (A48.8
# Other specified bacterial diseases )
# A50 (A50
# Congenital syphilis ) ->
#   - A50.0 (A50.0
# Early congenital syphilis, symptomatic )
#   - A50.01 (A50.01
# Early congenital syphilitic oculopathy )
#   - A50.02 (A50.02
# Early congenital syphilitic osteochondropathy )
#   - A50.03 (A50.03
# Early congenital syphilitic pharyngitis )
#   - A50.04 (A50.04
# Early congenital syphilitic pneumonia )
#   - A50.05 (A50.05
# Early congenital syphilitic rhinitis  )
#   - A50.06 (A50.06
# Early cutaneous congenital syphilis )
#   - A50.07 (A50.07
# Early mucocutaneous congenital syphilis )
#   - A50.08 (A50.08
# Early visceral congenital syphilis )
#   - A50.09 (A50.09
# Other early congenital syphilis, symptomatic )
#   - A50.1 (A50.1
# Early congenital syphilis, latent )
#   - A50.2 (A50.2
# Early congenital syphilis, unspecified )
#   - A50.3 (A50.3
# Late congenital syphilitic oculopathy )
#   - A50.30 (A50.30
# Late congenital syphilitic oculopathy, unspecified )
#   - A50.31 (A50.31
# Late congenital syphilitic interstitial keratitis )
#   - A50.32 (A50.32
# Late congenital syphilitic chorioretinitis )
#   - A50.39 (A50.39
# Other late congenital syphilitic oculopathy )
#   - A50.4 (A50.4
# Late congenital neurosyphilis [juvenile neurosyphilis] )
#   - A50.40 (A50.40
# Late congenital neurosyphilis, unspecified )
#   - A50.41 (A50.41
# Late congenital syphilitic meningitis )
#   - A50.42 (A50.42
# Late congenital syphilitic encephalitis )
#   - A50.43 (A50.43
# Late congenital syphilitic polyneuropathy )
#   - A50.44 (A50.44
# Late congenital syphilitic optic nerve atrophy )
#   - A50.45 (A50.45
# Juvenile general paresis )
#   - A50.49 (A50.49
# Other late congenital neurosyphilis )
#   - A50.5 (A50.5
# Other late congenital syphilis, symptomatic )
#   - A50.51 (A50.51
# Clutton's joints )
#   - A50.52 (A50.52
# Hutchinson's teeth )
#   - A50.53 (A50.53
# Hutchinson?s triad )
#   - A50.54 (A50.54
# Late congenital cardiovascular syphilis )
#   - A50.55 (A50.55
# Late congenital syphilitic arthropathy )
#   - A50.56 (A50.56
# Late congenital syphilitic osteochondropathy )
#   - A50.57 (A50.57
# Syphilitic saddle nose )
#   - A50.59 (A50.59
# Other late congenital syphilis, symptomatic )
#   - A50.6 (A50.6
# Late congenital syphilis, latent )
#   - A50.7 (A50.7
# Late congenital syphilis, unspecified )
#   - A50.9 (A50.9
# Congenital syphilis, unspecified )
# A51 (A51
# Early syphilis ) ->
#   - A51.0 (A51.0
# Primary genital syphilis )
#   - A51.1 (A51.1
# Primary anal syphilis )
#   - A51.2 (A51.2
# Primary syphilis of other sites )
#   - A51.3 (A51.3
# Secondary syphilis of skin and mucous membranes )
#   - A51.31 (A51.31
# Condyloma latum )
#   - A51.32 (A51.32
# Syphilitic alopecia )
#   - A51.39 (A51.39
# Other secondary syphilis of skin )
#   - A51.4 (A51.4
# Other secondary syphilis )
#   - A51.41 (A51.41
# Secondary syphilitic meningitis )
#   - A51.42 (A51.42
# Secondary syphilitic female pelvic disease )
#   - A51.43 (A51.43
# Secondary syphilitic oculopathy )
#   - A51.44 (A51.44
# Secondary syphilitic nephritis )
#   - A51.45 (A51.45
# Secondary syphilitic hepatitis )
#   - A51.46 (A51.46
# Secondary syphilitic osteopathy )
#   - A51.49 (A51.49
# Other secondary syphilitic conditions )
#   - A51.5 (A51.5
# Early syphilis, latent )
#   - A51.9 (A51.9
# Early syphilis, unspecified )
# A52 (A52
# Late syphilis ) ->
#   - A52.0 (A52.0
# Cardiovascular and cerebrovascular syphilis )
#   - A52.00 (A52.00
# Cardiovascular syphilis, unspecified )
#   - A52.01 (A52.01
# Syphilitic aneurysm of aorta )
#   - A52.02 (A52.02
# Syphilitic aortitis )
#   - A52.03 (A52.03
# Syphilitic endocarditis )
#   - A52.04 (A52.04
# Syphilitic cerebral arteritis )
#   - A52.05 (A52.05
# Other cerebrovascular syphilis )
#   - A52.06 (A52.06
# Other syphilitic heart involvement )
#   - A52.09 (A52.09
# Other cardiovascular syphilis )
#   - A52.1 (A52.1
# Symptomatic neurosyphilis )
#   - A52.10 (A52.10
# Symptomatic neurosyphilis, unspecified )
#   - A52.11 (A52.11
# Tabes dorsalis )
#   - A52.12 (A52.12
# Other cerebrospinal syphilis )
#   - A52.13 (A52.13
# Late syphilitic meningitis )
#   - A52.14 (A52.14
# Late syphilitic encephalitis )
#   - A52.15 (A52.15
# Late syphilitic neuropathy )
#   - A52.16 (A52.16
# Charcot's arthropathy (tabetic) )
#   - A52.17 (A52.17
# General paresis )
#   - A52.19 (A52.19
# Other symptomatic neurosyphilis )
#   - A52.2 (A52.2
# Asymptomatic neurosyphilis )
#   - A52.3 (A52.3
# Neurosyphilis, unspecified )
#   - A52.7 (A52.7
# Other symptomatic late syphilis )
#   - A52.71 (A52.71
# Late syphilitic oculopathy )
#   - A52.72 (A52.72
# Syphilis of lung and bronchus )
#   - A52.73 (A52.73
# Symptomatic late syphilis of other respiratory organs )
#   - A52.74 (A52.74
# Syphilis of liver and other viscera )
#   - A52.75 (A52.75
# Syphilis of kidney and ureter )
#   - A52.76 (A52.76
# Other genitourinary symptomatic late syphilis )
#   - A52.77 (A52.77
# Syphilis of bone and joint )
#   - A52.78 (A52.78
# Syphilis of other musculoskeletal tissue )
#   - A52.79 (A52.79
# Other symptomatic late syphilis )
#   - A52.8 (A52.8
# Late syphilis, latent )
#   - A52.9 (A52.9
# Late syphilis, unspecified )
# A53 (A53
# O98.11 ) ->
#   - A53.0 (A53.0
# Latent syphilis, unspecified as early or late )
#   - A53.9 (A53.9
# Syphilis, unspecified )
# A54 (A54
# Gonococcal infection ) ->
#   - A54.0 (A54.0
# Gonococcal infection of lower genitourinary tract without )
#   - A54.00 (A54.00
# Gonococcal infection of lower genitourinary tract, )
#   - A54.01 (A54.01
# Gonococcal cystitis and urethritis, unspecified  )
#   - A54.02 (A54.02
# Gonococcal vulvovaginitis, unspecified )
#   - A54.03 (A54.03
# Gonococcal cervicitis, unspecified )
#   - A54.09 (A54.09
# Other gonococcal infection of lower genitourinary tract )
#   - A54.1 (A54.1
# Gonococcal infection of lower genitourinary tract with )
#   - A54.2 (A54.2
# Gonococcal pelviperitonitis and other gonococcal )
#   - A54.21 (A54.21
# Gonococcal infection of kidney and ureter )
#   - A54.22 (A54.22
# Gonococcal prostatitis )
#   - A54.23 (A54.23
# Gonococcal infection of other male genital organs )
#   - A54.24 (A54.24
# Gonococcal female pelvic inflammatory disease )
#   - A54.29 (A54.29
# Other gonococcal genitourinary infections )
#   - A54.3 (A54.3
# Gonococcal infection of eye )
#   - A54.30 (A54.30
# Gonococcal infection of eye, unspecified )
#   - A54.31 (A54.31
# Gonococcal conjunctivitis )
#   - A54.32 (A54.32
# Gonococcal iridocyclitis )
#   - A54.33 (A54.33
# Gonococcal keratitis )
#   - A54.39 (A54.39
# Other gonococcal eye infection )
#   - A54.4 (A54.4
# Gonococcal infection of musculoskeletal system )
#   - A54.40 (A54.40
# Gonococcal infection of musculoskeletal system, )
#   - A54.41 (A54.41
# Gonococcal spondylopathy )
#   - A54.42 (A54.42
# Gonococcal arthritis )
#   - A54.43 (A54.43
# Gonococcal osteomyelitis )
#   - A54.49 (A54.49
# Gonococcal infection of other musculoskeletal tissue )
#   - A54.5 (A54.5
# Gonococcal pharyngitis )
#   - A54.6 (A54.6
# Gonococcal infection of anus and rectum )
#   - A54.8 (A54.8
# Other gonococcal infections )
#   - A54.81 (A54.81
# Gonococcal meningitis )
#   - A54.82 (A54.82
# Gonococcal brain abscess )
#   - A54.83 (A54.83
# Gonococcal heart infection )
#   - A54.84 (A54.84
# Gonococcal pneumonia )
#   - A54.85 (A54.85
# Gonococcal peritonitis )
#   - A54.86 (A54.86
# Gonococcal sepsis )
#   - A54.89 (A54.89
# Other gonococcal infections )
#   - A54.9 (A54.9
# Gonococcal infection, unspecified )
# A56 (A56
# Other sexually transmitted chlamydial diseases ) ->
#   - A56.0 (A56.0
# Chlamydial infection of lower genitourinary tract )
#   - A56.00 (A56.00
# Chlamydial infection of lower genitourinary tract, )
#   - A56.01 (A56.01
# Chlamydial cystitis and urethritis )
#   - A56.02 (A56.02
# Chlamydial vulvovaginitis )
#   - A56.09 (A56.09
# Other chlamydial infection of lower genitourinary tract )
#   - A56.1 (A56.1
# Chlamydial infection of pelviperitoneum and other )
#   - A56.11 (A56.11
# Chlamydial female pelvic inflammatory disease )
#   - A56.19 (A56.19
# Other chlamydial genitourinary infection )
#   - A56.2 (A56.2
# Chlamydial infection of genitourinary tract, unspecified  )
#   - A56.3 (A56.3
# Chlamydial infection of anus and rectum  )
#   - A56.4 (A56.4
# Chlamydial infection of pharynx  )
#   - A56.8 (A56.8
# Sexually transmitted chlamydial infection of other sites )
# A59 (A59
# Trichomoniasis ) ->
#   - A59.0 (A59.0
# Urogenital trichomoniasis )
#   - A59.00 (A59.00
# Urogenital trichomoniasis, unspecified )
#   - A59.01 (A59.01
# Trichomonal vulvovaginitis )
#   - A59.02 (A59.02
# Trichomonal prostatitis )
#   - A59.03 (A59.03
# Trichomonal cystitis and urethritis )
#   - A59.09 (A59.09
# Other urogenital trichomoniasis )
#   - A59.8 (A59.8
# Trichomoniasis of other sites )
#   - A59.9 (A59.9
# Trichomoniasis, unspecified )
# A60 (A60
# Anogenital herpesviral [herpes simplex] infections ) ->
#   - A60.0 (A60.0
# Herpesviral infection of genitalia and urogenital tract )
#   - A60.00 (A60.00
# Herpesviral infection of urogenital system, unspecified )
#   - A60.01 (A60.01
# Herpesviral infection of penis )
#   - A60.02 (A60.02
# Herpesviral infection of other male genital organs )
#   - A60.03 (A60.03
# Herpesviral cervicitis )
#   - A60.04 (A60.04
# Herpesviral vulvovaginitis )
#   - A60.09 (A60.09
# Herpesviral infection of other urogenital tract )
#   - A60.1 (A60.1
# Herpesviral infection of perianal skin and rectum )
#   - A60.9 (A60.9
# Anogenital herpesviral infection, unspecified  )
# A63 (A63
# Other predominantly sexually transmitted diseases, not ) ->
#   - A63.0 (A63.0
# Anogenital (venereal) warts )
#   - A63.8 (A63.8
# Other specified predominantly sexually transmitted diseases )
# A66 (A66
# Yaws ) ->
#   - A66.0 (A66.0
# Initial lesions of yaws )
#   - A66.1 (A66.1
# Multiple papillomata and wet crab yaws )
#   - A66.2 (A66.2
# Other early skin lesions of yaws )
#   - A66.3 (A66.3
# Hyperkeratosis of yaws )
#   - A66.4 (A66.4
# Gummata and ulcers of yaws )
#   - A66.5 (A66.5
# Gangosa )
#   - A66.6 (A66.6
# Bone and joint lesions of yaws )
#   - A66.7 (A66.7
# Other manifestations of yaws )
#   - A66.8 (A66.8
# Latent yaws )
#   - A66.9 (A66.9
# Yaws, unspecified )
# A67 (A67
# Pinta [carate] ) ->
#   - A67.0 (A67.0
# Primary lesions of pinta )
#   - A67.1 (A67.1
# Intermediate lesions of pinta )
#   - A67.2 (A67.2
# Late lesions of pinta )
#   - A67.3 (A67.3
# Mixed lesions of pinta )
#   - A67.9 (A67.9
# Pinta, unspecified )
# A68 (A68
# Relapsing fevers ) ->
#   - A68.0 (A68.0
# Louse-borne relapsing fever )
#   - A68.1 (A68.1
# Tick-borne relapsing fever )
#   - A68.9 (A68.9
# Relapsing fever, unspecified )
# A71 (A71
# Trachoma ) ->
#   - A71.0 (A71.0
# Initial stage of trachoma )
#   - A71.1 (A71.1
# Active stage of trachoma )
#   - A71.9 (A71.9
# Trachoma, unspecified )
# A75 (A75
# Typhus fever  ) ->
#   - A75.0 (A75.0
# Epidemic louse-borne typhus fever due to Rickettsia )
#   - A75.1 (A75.1
# Recrudescent typhus [Brill's disease] )
#   - A75.2 (A75.2
# Typhus fever due to Rickettsia typhi )
#   - A75.3 (A75.3
# Typhus fever due to Rickettsia tsutsugamushi )
#   - A75.9 (A75.9
# Typhus fever, unspecified )
# A77 (A77
# Spotted fever [tick-borne rickettsioses] ) ->
#   - A77.0 (A77.0
# Spotted fever due to Rickettsia rickettsii )
#   - A77.1 (A77.1
# Spotted fever due to Rickettsia conorii )
#   - A77.2 (A77.2
# Spotted fever due to Rickettsia siberica )
#   - A77.3 (A77.3
# Spotted fever due to Rickettsia australis )
#   - A77.4 (A77.4
# Ehrlichiosis )
#   - A77.40 (A77.40
# Ehrlichiosis, unspecified )
#   - A77.41 (A77.41
# Ehrlichiosis chafeensis [E. chafeensis] )
#   - A77.49 (A77.49
# Other ehrlichiosis )
#   - A77.8 (A77.8
# Other spotted fevers )
#   - A77.9 (A77.9
# Spotted fever, unspecified )
# A80 (A80
# Acute poliomyelitis ) ->
#   - A80.0 (A80.0
# Acute paralytic poliomyelitis, vaccine-associated )
#   - A80.1 (A80.1
# Acute paralytic poliomyelitis, wild virus, imported )
#   - A80.2 (A80.2
# Acute paralytic poliomyelitis, wild virus, indigenous )
#   - A80.3 (A80.3
# Acute paralytic poliomyelitis, other and unspecified )
#   - A80.30 (A80.30
# Acute paralytic poliomyelitis, unspecified )
#   - A80.39 (A80.39
# Other acute paralytic poliomyelitis )
#   - A80.4 (A80.4
# Acute nonparalytic poliomyelitis )
#   - A80.9 (A80.9
# Acute poliomyelitis, unspecified )
# A81 (A81
# Atypical virus infections of central nervous system ) ->
#   - A81.0 (A81.0
# Creutzfeldt-Jakob disease )
#   - A81.00 (A81.00
# Creutzfeldt-Jakob disease, unspecified )
#   - A81.01 (A81.01
# Variant Creutzfeldt-Jakob disease )
#   - A81.09 (A81.09
# Other Creutzfeldt-Jakob disease )
#   - A81.1 (A81.1
# Subacute sclerosing panencephalitis )
#   - A81.2 (A81.2
# Progressive multifocal leukoencephalopathy )
#   - A81.8 (A81.8
# Other atypical virus infections of central nervous system )
#   - A81.81 (A81.81
# Kuru )
#   - A81.82 (A81.82
# Gerstmann-Sträussler-Scheinker syndrome )
#   - A81.83 (A81.83
# Fatal familial insomnia )
#   - A81.89 (A81.89
# Other atypical virus infections of central nervous system )
#   - A81.9 (A81.9
# Atypical virus infection of central nervous system, unspecified )
# A82 (A82
# Rabies ) ->
#   - A82.0 (A82.0
# Sylvatic rabies )
#   - A82.1 (A82.1
# Urban rabies )
#   - A82.9 (A82.9
# Rabies, unspecified  )
# A83 (A83
# Mosquito-borne viral encephalitis ) ->
#   - A83.0 (A83.0
# Japanese encephalitis )
#   - A83.1 (A83.1
# Western equine encephalitis )
#   - A83.2 (A83.2
# Eastern equine encephalitis )
#   - A83.3 (A83.3
# St Louis encephalitis )
#   - A83.4 (A83.4
# Australian encephalitis )
#   - A83.5 (A83.5
# California encephalitis )
#   - A83.6 (A83.6
# Rocio virus disease )
#   - A83.8 (A83.8
# Other mosquito-borne viral encephalitis )
#   - A83.9 (A83.9
# Mosquito-borne viral encephalitis, unspecified )
# A84 (A84
# Tick-borne viral encephalitis ) ->
#   - A84.0 (A84.0
# Far Eastern tick-borne encephalitis [Russian spring-summer )
#   - A84.1 (A84.1
# Central European tick-borne encephalitis )
#   - A84.8 (A84.8
# Other tick-borne viral encephalitis )
#   - A84.9 (A84.9
# Tick-borne viral encephalitis, unspecified )
# A85 (A85
# Other viral encephalitis, not elsewhere classified ) ->
#   - A85.0 (A85.0
# Enteroviral encephalitis )
#   - A85.1 (A85.1
# Adenoviral encephalitis )
#   - A85.2 (A85.2
# Arthropod-borne viral encephalitis, unspecified )
#   - A85.8 (A85.8
# Other specified viral encephalitis )
# A87 (A87
# Viral meningitis ) ->
#   - A87.0 (A87.0
# Enteroviral meningitis )
#   - A87.1 (A87.1
# Adenoviral meningitis )
#   - A87.2 (A87.2
# Lymphocytic choriomeningitis  )
#   - A87.8 (A87.8
# Other viral meningitis )
#   - A87.9 (A87.9
# Viral meningitis, unspecified )
# A88 (A88
# Other viral infections of central nervous system, not ) ->
#   - A88.0 (A88.0
# Enteroviral exanthematous fever [Boston exanthem] )
#   - A88.1 (A88.1
# Epidemic vertigo )
#   - A88.8 (A88.8
# Other specified viral infections of central nervous system )
# A92 (A92
# Poisoning by other bacterial vaccines, intentional ) ->
#   - A92.0 (A92.0
# Chikungunya virus disease )
#   - A92.1 (A92.1
# O'nyong-nyong fever )
#   - A92.2 (A92.2
# Venezuelan equine fever )
#   - A92.3 (A92.3
# West Nile virus infection )
#   - A92.30 (A92.30
# West Nile virus infection, unspecified )
#   - A92.31 (A92.31
# West Nile virus infection with encephalitis )
#   - A92.32 (A92.32
# West Nile virus infection with other neurologic )
#   - A92.39 (A92.39
# West Nile virus infection with other complications )
#   - A92.4 (A92.4
# Rift Valley fever )
#   - A92.8 (A92.8
# Other specified mosquito-borne viral fevers )
#   - A92.9 (A92.9
# Mosquito-borne viral fever, unspecified )
# A93 (A93
# Poisoning by other bacterial vaccines, assault ) ->
#   - A93.0 (A93.0
# Oropouche virus disease )
#   - A93.1 (A93.1
# Sandfly fever )
#   - A93.2 (A93.2
# Colorado tick fever )
#   - A93.8 (A93.8
# Other specified arthropod-borne viral fevers )
# A95 (A95
# Adverse effect of other bacterial vaccines ) ->
#   - A95.0 (A95.0
# Sylvatic yellow fever )
#   - A95.1 (A95.1
# Urban yellow fever )
#   - A95.9 (A95.9
# Yellow fever, unspecified )
# A96 (A96
# Underdosing of other bacterial vaccines ) ->
#   - A96.0 (A96.0
# Junin hemorrhagic fever )
#   - A96.1 (A96.1
# Machupo hemorrhagic fever )
#   - A96.2 (A96.2
# Lassa fever )
#   - A96.8 (A96.8
# Other arenaviral hemorrhagic fevers )
#   - A96.9 (A96.9
# Arenaviral hemorrhagic fever, unspecified  )
# A98 (A98
# Other viral hemorrhagic fevers, not elsewhere classified ) ->
#   - A98.0 (A98.0
# Crimean-Congo hemorrhagic fever )
#   - A98.1 (A98.1
# Omsk hemorrhagic fever )
#   - A98.2 (A98.2
# Kyasanur Forest disease )
#   - A98.3 (A98.3
# Marburg virus disease )
#   - A98.4 (A98.4
# Ebola virus disease )
#   - A98.5 (A98.5
# Hemorrhagic fever with renal syndrome )
#   - A98.8 (A98.8
# Other specified viral hemorrhagic fevers )
# B00 (B00
# Herpesviral [herpes simplex] infections ) ->
#   - B00.0 (B00.0
# Eczema herpeticum )
#   - B00.1 (B00.1
# Herpesviral vesicular dermatitis )
#   - B00.2 (B00.2
# Herpesviral gingivostomatitis and pharyngotonsillitis )
#   - B00.3 (B00.3
# Herpesviral meningitis )
#   - B00.4 (B00.4
# Herpesviral encephalitis )
#   - B00.5 (B00.5
# Herpesviral ocular disease )
#   - B00.50 (B00.50
# Herpesviral ocular disease, unspecified )
#   - B00.51 (B00.51
# Herpesviral iridocyclitis )
#   - B00.52 (B00.52
# Herpesviral keratitis )
#   - B00.53 (B00.53
# Herpesviral conjunctivitis )
#   - B00.59 (B00.59
# Other herpesviral disease of eye )
#   - B00.7 (B00.7
# Disseminated herpesviral disease )
#   - B00.8 (B00.8
# Other forms of herpesviral infections )
#   - B00.81 (B00.81
# Herpesviral hepatitis )
#   - B00.82 (B00.82
# Herpes simplex myelitis )
#   - B00.89 (B00.89
# Other herpesviral infection )
#   - B00.9 (B00.9
# Herpesviral infection, unspecified )
# B01 (B01
# Varicella [chickenpox] ) ->
#   - B01.0 (B01.0
# Varicella meningitis )
#   - B01.1 (B01.1
# Varicella encephalitis, myelitis and encephalomyelitis )
#   - B01.11 (B01.11
# Varicella encephalitis and encephalomyelitis )
#   - B01.12 (B01.12
# Varicella myelitis )
#   - B01.2 (B01.2
# Varicella pneumonia )
#   - B01.8 (B01.8
# Varicella with other complications )
#   - B01.81 (B01.81
# Varicella keratitis )
#   - B01.89 (B01.89
# Other varicella complications )
#   - B01.9 (B01.9
# Varicella without complication )
# B02 (B02
# Zoster [herpes zoster] ) ->
#   - B02.0 (B02.0
# Zoster encephalitis )
#   - B02.1 (B02.1
# Zoster meningitis )
#   - B02.2 (B02.2
# Zoster with other nervous system involvement )
#   - B02.21 (B02.21
# Postherpetic geniculate ganglionitis )
#   - B02.22 (B02.22
# Postherpetic trigeminal neuralgia )
#   - B02.23 (B02.23
# Postherpetic polyneuropathy )
#   - B02.24 (B02.24
# Postherpetic myelitis )
#   - B02.29 (B02.29
# Other postherpetic nervous system involvement )
#   - B02.3 (B02.3
# Zoster ocular disease )
#   - B02.30 (B02.30
# Zoster ocular disease, unspecified )
#   - B02.31 (B02.31
# Zoster conjunctivitis )
#   - B02.32 (B02.32
# Zoster iridocyclitis )
#   - B02.33 (B02.33
# Zoster keratitis )
#   - B02.34 (B02.34
# Zoster scleritis )
#   - B02.39 (B02.39
# Other herpes zoster eye disease )
#   - B02.7 (B02.7
# Disseminated zoster )
#   - B02.8 (B02.8
# Zoster with other complications )
#   - B02.9 (B02.9
# Zoster without complications )
# B05 (B05
# Measles ) ->
#   - B05.0 (B05.0
# Measles complicated by encephalitis )
#   - B05.1 (B05.1
# Measles complicated by meningitis )
#   - B05.2 (B05.2
# Measles complicated by pneumonia )
#   - B05.3 (B05.3
# Measles complicated by otitis media )
#   - B05.4 (B05.4
# Measles with intestinal complications )
#   - B05.8 (B05.8
# Measles with other complications )
#   - B05.81 (B05.81
# Measles keratitis and keratoconjunctivitis )
#   - B05.89 (B05.89
# Other measles complications )
#   - B05.9 (B05.9
# Measles without complication )
# B06 (B06
# Rubella [German measles] ) ->
#   - B06.0 (B06.0
# Rubella with neurological complications )
#   - B06.00 (B06.00
# Rubella with neurological complication, unspecified )
#   - B06.01 (B06.01
# Rubella encephalitis )
#   - B06.02 (B06.02
# Rubella meningitis )
#   - B06.09 (B06.09
# Other neurological complications of rubella )
#   - B06.8 (B06.8
# Rubella with other complications )
#   - B06.81 (B06.81
# Rubella pneumonia )
#   - B06.82 (B06.82
# Rubella arthritis )
#   - B06.89 (B06.89
# Other rubella complications )
#   - B06.9 (B06.9
# Rubella without complication )
# B07 (B07
# Viral warts ) ->
#   - B07.0 (B07.0
# Plantar wart )
#   - B07.8 (B07.8
# Other viral warts )
#   - B07.9 (B07.9
# Viral wart, unspecified )
# B08 (B08
# Other viral infections characterized by skin and mucous ) ->
#   - B08.0 (B08.0
# Other orthopoxvirus infections )
#   - B08.01 (B08.01
# Cowpox and vaccinia not from vaccine )
#   - B08.02 (B08.02
# Orf virus disease )
#   - B08.03 (B08.03
# Pseudocowpox [milker's node] )
#   - B08.04 (B08.04
# Paravaccinia, unspecified )
#   - B08.09 (B08.09
# Other orthopoxvirus infections )
#   - B08.1 (B08.1
# Molluscum contagiosum )
#   - B08.2 (B08.2
# Exanthema subitum [sixth disease] )
#   - B08.20 (B08.20
# Exanthema subitum [sixth disease], unspecified )
#   - B08.21 (B08.21
# Exanthema subitum [sixth disease] due to human )
#   - B08.22 (B08.22
# Exanthema subitum [sixth disease] due to human )
#   - B08.3 (B08.3
# Erythema infectiosum [fifth disease] )
#   - B08.4 (B08.4
# Enteroviral vesicular stomatitis with exanthem )
#   - B08.5 (B08.5
# Enteroviral vesicular pharyngitis  )
#   - B08.6 (B08.6
# Parapoxvirus infections )
#   - B08.60 (B08.60
# Parapoxvirus infection, unspecified )
#   - B08.61 (B08.61
# Bovine stomatitis )
#   - B08.62 (B08.62
# Sealpox )
#   - B08.69 (B08.69
# Other parapoxvirus infections )
#   - B08.7 (B08.7
# Yatapoxvirus infections )
#   - B08.70 (B08.70
# Yatapoxvirus infection, unspecified )
#   - B08.71 (B08.71
# Tanapox virus disease )
#   - B08.72 (B08.72
# Yaba pox virus disease )
#   - B08.79 (B08.79
# Other yatapoxvirus infections )
#   - B08.8 (B08.8
# Other specified viral infections characterized by skin and )
# B15 (B15
# Adverse effect of smallpox vaccines ) ->
#   - B15.0 (B15.0
# Hepatitis A with hepatic coma )
#   - B15.9 (B15.9
# Hepatitis A without hepatic coma )
# B16 (B16
# Underdosing of smallpox vaccines ) ->
#   - B16.0 (B16.0
# Acute hepatitis B with delta-agent with hepatic coma )
#   - B16.1 (B16.1
# Acute hepatitis B with delta-agent without hepatic coma )
#   - B16.2 (B16.2
# Acute hepatitis B without delta-agent with hepatic coma )
#   - B16.9 (B16.9
# Acute hepatitis B without delta-agent and without hepatic )
# B17 (B17
# Other acute viral hepatitis ) ->
#   - B17.0 (B17.0
# Acute delta-(super) infection of hepatitis B carrier )
#   - B17.1 (B17.1
# Acute hepatitis C )
#   - B17.10 (B17.10
# Acute hepatitis C without hepatic coma )
#   - B17.11 (B17.11
# Acute hepatitis C with hepatic coma )
#   - B17.2 (B17.2
# Acute hepatitis E )
#   - B17.8 (B17.8
# Other specified acute viral hepatitis )
#   - B17.9 (B17.9
# Acute viral hepatitis, unspecified )
# B18 (B18
# Chronic viral hepatitis ) ->
#   - B18.0 (B18.0
# Chronic viral hepatitis B with delta-agent )
#   - B18.1 (B18.1
# Chronic viral hepatitis B without delta-agent )
#   - B18.2 (B18.2
# Chronic viral hepatitis C )
#   - B18.8 (B18.8
# Other chronic viral hepatitis )
#   - B18.9 (B18.9
# Chronic viral hepatitis, unspecified )
# B25 (B25
# Cytomegaloviral disease ) ->
#   - B25.0 (B25.0
# Cytomegaloviral pneumonitis )
#   - B25.1 (B25.1
# Cytomegaloviral hepatitis )
#   - B25.2 (B25.2
# Cytomegaloviral pancreatitis )
#   - B25.8 (B25.8
# Other cytomegaloviral diseases )
#   - B25.9 (B25.9
# Cytomegaloviral disease, unspecified  )
# B26 (B26
# Mumps ) ->
#   - B26.0 (B26.0
# Mumps orchitis )
#   - B26.1 (B26.1
# Mumps meningitis )
#   - B26.2 (B26.2
# Mumps encephalitis )
#   - B26.3 (B26.3
# Mumps pancreatitis )
#   - B26.8 (B26.8
# Mumps with other complications )
#   - B26.81 (B26.81
# Mumps hepatitis )
#   - B26.82 (B26.82
# Mumps myocarditis )
#   - B26.83 (B26.83
# Mumps nephritis )
#   - B26.84 (B26.84
# Mumps polyneuropathy )
#   - B26.85 (B26.85
# Mumps arthritis )
#   - B26.89 (B26.89
# Other mumps complications )
#   - B26.9 (B26.9
# Mumps without complication )
# B27 (B27
# Infectious mononucleosis ) ->
#   - B27.0 (B27.0
# Gammaherpesviral mononucleosis )
#   - B27.00 (B27.00
# Gammaherpesviral mononucleosis without )
#   - B27.01 (B27.01
# Gammaherpesviral mononucleosis with )
#   - B27.02 (B27.02
# Gammaherpesviral mononucleosis with meningitis )
#   - B27.09 (B27.09
# Gammaherpesviral mononucleosis with other )
#   - B27.1 (B27.1
# Cytomegaloviral mononucleosis )
#   - B27.10 (B27.10
# Cytomegaloviral mononucleosis without complications )
#   - B27.11 (B27.11
# Cytomegaloviral mononucleosis with polyneuropathy )
#   - B27.12 (B27.12
# Cytomegaloviral mononucleosis with meningitis )
#   - B27.19 (B27.19
# Cytomegaloviral mononucleosis with other )
#   - B27.8 (B27.8
# Other infectious mononucleosis )
#   - B27.80 (B27.80
# Other infectious mononucleosis without complication )
#   - B27.81 (B27.81
# Other infectious mononucleosis with polyneuropathy )
#   - B27.82 (B27.82
# Other infectious mononucleosis with meningitis )
#   - B27.89 (B27.89
# Other infectious mononucleosis with other )
#   - B27.9 (B27.9
# with .9) )
#   - B27.90 (B27.90
# Infectious mononucleosis, unspecified without )
#   - B27.91 (B27.91
# Infectious mononucleosis, unspecified with )
#   - B27.92 (B27.92
# Infectious mononucleosis, unspecified with meningitis )
#   - B27.99 (B27.99
# Infectious mononucleosis, unspecified with other )
#   - B27.9 (B27.9
# with .9) )
#   - B27.9 (B27.9
# with .9) )
# B30 (B30
# Viral conjunctivitis ) ->
#   - B30.0 (B30.0
# Keratoconjunctivitis due to adenovirus )
#   - B30.1 (B30.1
# Conjunctivitis due to adenovirus )
#   - B30.2 (B30.2
# Viral pharyngoconjunctivitis )
#   - B30.3 (B30.3
# Acute epidemic hemorrhagic conjunctivitis (enteroviral)  )
#   - B30.8 (B30.8
# Other viral conjunctivitis )
#   - B30.9 (B30.9
# Viral conjunctivitis, unspecified )
# B33 (B33
# Other viral diseases, not elsewhere classified ) ->
#   - B33.0 (B33.0
# Epidemic myalgia )
#   - B33.1 (B33.1
# Ross River disease )
#   - B33.2 (B33.2
# Viral carditis )
#   - B33.20 (B33.20
# Viral carditis, unspecified )
#   - B33.21 (B33.21
# Viral endocarditis )
#   - B33.22 (B33.22
# Viral myocarditis )
#   - B33.23 (B33.23
# Viral pericarditis )
#   - B33.24 (B33.24
# Viral cardiomyopathy )
#   - B33.3 (B33.3
# Retrovirus infections, not elsewhere classified )
#   - B33.4 (B33.4
# Hantavirus (cardio)-pulmonary syndrome [HPS] [HCPS] )
#   - B33.8 (B33.8
# Other specified viral diseases )
# B35 (B35
# Dermatophytosis ) ->
#   - B35.0 (B35.0
# Tinea barbae and tinea capitis  )
#   - B35.1 (B35.1
# Tinea unguium )
#   - B35.2 (B35.2
# Tinea manuum )
#   - B35.3 (B35.3
# Tinea pedis )
#   - B35.4 (B35.4
# Tinea corporis )
#   - B35.5 (B35.5
# Tinea imbricata )
#   - B35.6 (B35.6
# Tinea cruris )
#   - B35.8 (B35.8
# Other dermatophytoses )
#   - B35.9 (B35.9
# Dermatophytosis, unspecified )
# B36 (B36
# Other superficial mycoses ) ->
#   - B36.0 (B36.0
# Pityriasis versicolor )
#   - B36.1 (B36.1
# Tinea nigra )
#   - B36.2 (B36.2
# White piedra )
#   - B36.3 (B36.3
# Black piedra )
#   - B36.8 (B36.8
# Other specified superficial mycoses )
#   - B36.9 (B36.9
# ...
#   - Z75.5 (Z75.5
# Holiday relief care )
#   - Z75.8 (Z75.8
# Other problems related to medical facilities and other health )
#   - Z75.9 (Z75.9
# Unspecified problem related to medical facilities and other )
# Z77 (Z77
# Other contact with and (suspected) exposures hazardous ) ->
#   - Z77.0 (Z77.0
# Contact with and (suspected) exposure to hazardous, chiefly )
#   - Z77.01 (Z77.01
# Contact with and (suspected) exposure to hazardous )
#   - Z77.02 (Z77.02
# Contact with and (suspected) exposure to hazardous )
#   - Z77.09 (Z77.09
# Contact with and (suspected) exposure to other )
#   - Z77.1 (Z77.1
# Contact with and (suspected) exposure to environmental pollution and )
#   - Z77.11 (Z77.11
# Contact with and (suspected) exposure to )
#   - Z77.12 (Z77.12
# Contact with and (suspected) exposure to hazards in )
#   - Z77.2 (Z77.2
# Contact with and (suspected ) exposure to other hazardous substances )
#   - Z77.21 (Z77.21
# Contact with and (suspected) exposure to potentially )
#   - Z77.22 (Z77.22
# Contact with and (suspected) exposure to environmental )
#   - Z77.29 (Z77.29
# Contact with and (suspected ) exposure to other hazardous )
#   - Z77.9 (Z77.9
# Other contact with and (suspected) exposures hazardous to health )
# Z78 (Z78
# Other specified health status ) ->
#   - Z78.0 (Z78.0
# Asymptomatic menopausal state )
#   - Z78.9 (Z78.9
# Other specified health status )
# Z79 (Z79
# Long term (current) drug therapy ) ->
#   - Z79.0 (Z79.0
# Long term (current) use of anticoagulants and )
#   - Z79.01 (Z79.01
# Long term (current) use of anticoagulants )
#   - Z79.02 (Z79.02
# Long term (current) use of )
#   - Z79.1 (Z79.1
# Long term (current) use of non-steroidal anti-inflammatories )
#   - Z79.2 (Z79.2
# Long term (current) use of antibiotics )
#   - Z79.3 (Z79.3
# Long term (current) use of hormonal contraceptives )
#   - Z79.4 (Z79.4
# Long term (current) use of insulin )
#   - Z79.5 (Z79.5
# Long term (current) use of steroids )
#   - Z79.51 (Z79.51
# Long term (current) use of inhaled steroids )
#   - Z79.52 (Z79.52
# Long term (current) use of systemic steroids )
#   - Z79.8 (Z79.8
# Other long term (current) drug therapy )
#   - Z79.81 (Z79.81
# Long term (current) use of agents affecting )
#   - Z79.82 (Z79.82
# Long term (current) use of aspirin )
#   - Z79.89 (Z79.89
# Other long term (current) drug therapy )
# Z80 (Z80
# Family history of primary malignant neoplasm ) ->
#   - Z80.0 (Z80.0
# Family history of malignant neoplasm of digestive organs )
#   - Z80.4 (Z80.4
# Family history of malignant neoplasm of genital organs )
#   - Z80.41 (Z80.41
# Family history of malignant neoplasm of ovary )
#   - Z80.42 (Z80.42
# Family history of malignant neoplasm of prostate )
#   - Z80.43 (Z80.43
# Family history of malignant neoplasm of testis )
#   - Z80.49 (Z80.49
# Family history of malignant neoplasm of other genital )
#   - Z80.5 (Z80.5
# Family history of malignant neoplasm of urinary tract )
#   - Z80.52 (Z80.52
# Family history of malignant neoplasm of bladder )
#   - Z80.59 (Z80.59
# Family history of malignant neoplasm of other urinary )
#   - Z80.6 (Z80.6
# Family history of leukemia )
#   - Z80.8 (Z80.8
# Family history of malignant neoplasm of other organs or )
# Z83 (Z83
# Family history of other specific disorders ) ->
#   - Z83.0 (Z83.0
# Family history of human immunodeficiency virus [HIV] disease )
#   - Z83.49 (Z83.49
# Family history of other endocrine, nutritional and metabolic )
#   - Z83.5 (Z83.5
# Family history of eye and ear disorders )
#   - Z83.6 (Z83.6
# Family history of other diseases of the respiratory system )
#   - Z83.7 (Z83.7
# Family history of diseases of the digestive system )
#   - Z83.79 (Z83.79
# Family history of other diseases of the digestive system )
# Z84 (Z84
# Family history of other conditions ) ->
#   - Z84.0 (Z84.0
# Family history of diseases of the skin and subcutaneous )
#   - Z84.8 (Z84.8
# Family history of other specified conditions )
#   - Z84.81 (Z84.81
# Family history of carrier of genetic disease )
#   - Z84.89 (Z84.89
# Family history of other specified conditions )
# Z85 (Z85
# Personal history of malignant neoplasm ) ->
#   - Z85.0 (Z85.0
# Personal history of malignant neoplasm of digestive organs )
#   - Z85.00 (Z85.00
# Personal history of malignant neoplasm of unspecified )
#   - Z85.01 (Z85.01
# Personal history of malignant neoplasm of esophagus )
#   - Z85.02 (Z85.02
# Personal history of malignant neoplasm of )
#   - Z85.1 (Z85.1
# Personal history of malignant neoplasm of trachea, bronchus )
#   - Z85.11 (Z85.11
# Personal history of malignant neoplasm of )
#   - Z85.20 (Z85.20
# Personal history of malignant neoplasm of unspecified )
#   - Z85.21 (Z85.21
# Personal history of malignant neoplasm of larynx )
#   - Z85.3 (Z85.3
# Personal history of malignant neoplasm of breast )
#   - Z85.4 (Z85.4
# Personal history of malignant neoplasm of genital organs )
#   - Z85.41 (Z85.41
# Personal history of malignant neoplasm of cervix uteri )
#   - Z85.42 (Z85.42
# Personal history of malignant neoplasm of other parts )
#   - Z85.43 (Z85.43
# Personal history of malignant neoplasm of ovary )
#   - Z85.44 (Z85.44
# Personal history of malignant neoplasm of other )
#   - Z85.45 (Z85.45
# Personal history of malignant neoplasm of unspecified )
#   - Z85.46 (Z85.46
# Personal history of malignant neoplasm of prostate )
#   - Z85.47 (Z85.47
# Personal history of malignant neoplasm of testis )
#   - Z85.48 (Z85.48
# Personal history of malignant neoplasm of epididymis )
#   - Z85.49 (Z85.49
# Personal history of malignant neoplasm of other male )
#   - Z85.5 (Z85.5
# Personal history of malignant neoplasm of urinary tract )
#   - Z85.50 (Z85.50
# Personal history of malignant neoplasm of unspecified )
#   - Z85.51 (Z85.51
# Personal history of malignant neoplasm of bladder )
#   - Z85.52 (Z85.52
# Personal history of malignant neoplasm of )
#   - Z85.59 (Z85.59
# Personal history of malignant neoplasm of other )
#   - Z85.6 (Z85.6
# Personal history of leukemia )
#   - Z85.7 (Z85.7
# Personal history of other malignant neoplasms of lymphoid, )
#   - Z85.71 (Z85.71
# Personal history of Hodgkin lymphoma )
#   - Z85.8 (Z85.8
# Personal history of malignant neoplasms of other organs and )
#   - Z85.81 (Z85.81
# Personal history of malignant neoplasm of )
#   - Z85.82 (Z85.82
# Personal history of malignant neoplasm of )
#   - Z85.84 (Z85.84
# Personal history of malignant neoplasm of )
#   - Z85.85 (Z85.85
# Personal history of malignant neoplasm of )
#   - Z85.89 (Z85.89
# Personal history of malignant neoplasm of other )
#   - Z85.9 (Z85.9
# Personal history of malignant neoplasm, unspecified )
# Z87 (Z87
# Personal history of other diseases and conditions ) ->
#   - Z87.0 (Z87.0
# Personal history of diseases of the respiratory system )
#   - Z87.09 (Z87.09
# Personal history of other diseases of the respiratory system )
#   - Z87.1 (Z87.1
# Personal history of diseases of the digestive system )
#   - Z87.19 (Z87.19
# Personal history of other diseases of the digestive )
#   - Z87.2 (Z87.2
# Personal history of diseases of the skin and subcutaneous )
#   - Z87.3 (Z87.3
# Personal history of diseases of the musculoskeletal system )
#   - Z87.31 (Z87.31
# Personal history of (healed) nontraumatic fracture )
#   - Z87.39 (Z87.39
# Personal history of other diseases of the )
#   - Z87.4 (Z87.4
# Personal history of diseases of the genitourinary system )
#   - Z87.42 (Z87.42
# Personal history of nephrotic syndrome )
#   - Z87.43 (Z87.43
# Personal history of urinary calculi )
#   - Z87.44 (Z87.44
# Personal history of cervical dysplasia )
#   - Z87.49 (Z87.49
# Personal history of other diseases of the genitourinary system )
#   - Z87.5 (Z87.5
# Personal history of complications of pregnancy, childbirth and )
#   - Z87.51 (Z87.51
# Personal history of pre-term labor )
#   - Z87.59 (Z87.59
# Personal history of other complications of pregnancy, )
#   - Z87.7 (Z87.7
# Personal history of congenital malformations and )
#   - Z87.71 (Z87.71
# Personal history of hypospadias )
#   - Z87.79 (Z87.79
# Personal history of other congenital malformations )
#   - Z87.8 (Z87.8
# Personal history of other specified conditions )
#   - Z87.81 (Z87.81
# Personal history of (healed) traumatic fracture )
#   - Z87.82 (Z87.82
# Personal history of other (healed) physical )
#   - Z87.89 (Z87.89
# Personal history of other specified )
# Z88 (Z88
# Allergy status to drugs, medicaments and biological ) ->
#   - Z88.0 (Z88.0
# Allergy status to penicillin )
#   - Z88.1 (Z88.1
# Allergy status to other antibiotic agents status )
#   - Z88.2 (Z88.2
# Allergy status to sulfonamides status )
#   - Z88.3 (Z88.3
# Allergy status to other anti-infective agents status )
#   - Z88.4 (Z88.4
# Allergy status to anesthetic agent status )
#   - Z88.5 (Z88.5
# Allergy status to narcotic agent status )
#   - Z88.6 (Z88.6
# Allergy status to analgesic agent status )
#   - Z88.7 (Z88.7
# Allergy status to serum and vaccine status )
#   - Z88.8 (Z88.8
# Allergy status to other drugs, medicaments and biological )
#   - Z88.9 (Z88.9
# Allergy status to unspecified drugs, medicaments and )
# Z89 (Z89
# Acquired absence of limb ) ->
#   - Z89.0 (Z89.0
# Acquired absence of thumb and other finger(s) )
#   - Z89.01 (Z89.01
# Acquired absence of thumb )
#   - Z89.02 (Z89.02
# Acquired absence of other finger(s) )
#   - Z89.1 (Z89.1
# Acquired absence of hand and wrist )
#   - Z89.11 (Z89.11
# Acquired absence of hand )
#   - Z89.12 (Z89.12
# Acquired absence of wrist )
#   - Z89.2 (Z89.2
# Acquired absence of upper limb above wrist )
#   - Z89.20 (Z89.20
# Acquired absence of upper limb, )
#   - Z89.21 (Z89.21
# Acquired absence of upper limb below )
#   - Z89.22 (Z89.22
# Acquired absence of upper limb above )
#   - Z89.23 (Z89.23
# Acquired absence of shoulder )
#   - Z89.4 (Z89.4
# Acquired absence of toe(s), foot, and ankle )
#   - Z89.41 (Z89.41
# Acquired absence of great toe )
#   - Z89.42 (Z89.42
# Acquired absence of other toe(s) )
#   - Z89.43 (Z89.43
# Acquired absence of foot )
#   - Z89.44 (Z89.44
# Acquired absence of ankle )
#   - Z89.5 (Z89.5
# Acquired absence of leg below knee )
#   - Z89.50 (Z89.50
# Acquired absence of leg knee, unspecified side )
#   - Z89.51 (Z89.51
# Acquired absence of right leg below knee )
#   - Z89.52 (Z89.52
# Acquired absence of left leg below knee )
#   - Z89.6 (Z89.6
# Acquired absence of leg above knee )
#   - Z89.61 (Z89.61
# Acquired absence of leg above knee )
#   - Z89.62 (Z89.62
# Acquired absence of hip )
#   - Z89.9 (Z89.9
# Acquired absence of limb, unspecified )
# Z90 (Z90
# Acquired absence of organs, not elsewhere classified ) ->
#   - Z90.0 (Z90.0
# Acquired absence of part of head and neck )
#   - Z90.01 (Z90.01
# Acquired absence of eye )
#   - Z90.02 (Z90.02
# Acquired absence of larynx )
#   - Z90.09 (Z90.09
# Acquired absence of other part of head and neck )
#   - Z90.1 (Z90.1
# Acquired absence of breast and nipple )
#   - Z90.10 (Z90.10
# Acquired absence of unspecified breast and nipple )
#   - Z90.11 (Z90.11
# Acquired absence of right breast and nipple )
#   - Z90.12 (Z90.12
# Acquired absence of left breast and nipple )
#   - Z90.13 (Z90.13
# Acquired absence of bilateral breasts and nipples )
#   - Z90.2 (Z90.2
# Acquired absence of lung [part of] )
#   - Z90.3 (Z90.3
# Acquired absence of stomach [part of] )
#   - Z90.4 (Z90.4
# Acquired absence of other parts of digestive tract )
#   - Z90.5 (Z90.5
# Acquired absence of kidney )
#   - Z90.6 (Z90.6
# Acquired absence of other parts of urinary tract )
#   - Z90.7 (Z90.7
# Acquired absence of genital organ(s) )
#   - Z90.71 (Z90.71
# Acquired absence of cervix and uterus )
#   - Z90.72 (Z90.72
# Acquired absence of ovaries )
#   - Z90.79 (Z90.79
# Acquired absence of other genital organ(s) )
#   - Z90.8 (Z90.8
# Acquired absence of other organs )
#   - Z90.81 (Z90.81
# Acquired absence of spleen )
#   - Z90.89 (Z90.89
# Acquired absence of other organs )
# Z97 (Z97
# Presence of other devices ) ->
#   - Z97.0 (Z97.0
# Presence of artificial eye )
#   - Z97.1 (Z97.1
# Presence of artificial limb (complete) (partial) )
#   - Z97.10 (Z97.10
# Presence of artificial limb (complete) (partial), )
#   - Z97.11 (Z97.11
# Presence of artificial right arm (complete) (partial) )
#   - Z97.12 (Z97.12
# Presence of artificial left arm (complete) (partial) )
#   - Z97.13 (Z97.13
# Presence of artificial right leg (complete) (partial) )
#   - Z97.14 (Z97.14
# Presence of artificial left leg (complete) (partial) )
#   - Z97.15 (Z97.15
# Presence of artificial arms, bilateral (complete) (partial) )
#   - Z97.16 (Z97.16
# Presence of artificial legs, bilateral (complete) (partial) )
#   - Z97.2 (Z97.2
# Presence of dental prosthetic device (complete) (partial) )
#   - Z97.3 (Z97.3
# Presence of spectacles and contact lenses )
#   - Z97.4 (Z97.4
# Presence of external hearing-aid )
#   - Z97.5 (Z97.5
# Presence of (intrauterine) contraceptive device )
#   - Z97.8 (Z97.8
# Presence of other specified devices )
# Z98 (Z98
# Other postprocedural states ) ->
#   - Z98.0 (Z98.0
# Intestinal bypass and anastomosis status )
#   - Z98.1 (Z98.1
# Arthrodesis status )
#   - Z98.2 (Z98.2
# Presence of cerebrospinal fluid drainage device )
#   - Z98.3 (Z98.3
# Post therapeutic collapse of lung status )
#   - Z98.4 (Z98.4
# Cataract extraction status )
#   - Z98.41 (Z98.41
# Cataract extraction status, right eye )
#   - Z98.42 (Z98.42
# Cataract extraction status, left eye )
#   - Z98.49 (Z98.49
# Cataract extraction status, unspecified eye )
#   - Z98.5 (Z98.5
# Sterilization status )
#   - Z98.51 (Z98.51
# Tubal ligation status )
#   - Z98.52 (Z98.52
# Vasectomy status )
#   - Z98.6 (Z98.6
# Angioplasty status )
#   - Z98.61 (Z98.61
# Coronary angioplasty status )
#   - Z98.62 (Z98.62
# Peripheral vascular angioplasty status )
#   - Z98.8 (Z98.8
# Other specified postprocedural states )
#   - Z98.81 (Z98.81
# Dental procedure status )
#   - Z98.82 (Z98.82
# Breast implant status )
#   - Z98.83 (Z98.83
# Filtering (vitreous) bleb after glaucoma surgery status )
#   - Z98.84 (Z98.84
# Bariatric surgery status )
#   - Z98.85 (Z98.85
# Transplanted organ removal status )
#   - Z98.86 (Z98.86
# Personal history of breast implant removal )
#   - Z98.87 (Z98.87
# Personal history of in utero procedure )
#   - Z98.89 (Z98.89
# Other specified postprocedural states )
# O97 () ->
#   - O97.2 (O97.2
# P00.6 Newborn (suspected to be) affected by surgical procedure on )
# Z81 () ->
#   - Z81.0 (Z81.0
# Family history of mental retardation )
#   - Z81.2 (Z81.2
# Family history of tobacco abuse and dependence )
#   - Z81.3 (Z81.3
# Family history of other psychoactive substance abuse and )
# Z82 () ->
#   - Z82.0 (Z82.0
# Family history of epilepsy and other diseases of the nervous )
#   - Z82.2 (Z82.2
# Family history of deafness and hearing loss )
#   - Z82.49 (Z82.49
# Family history of ischemic heart disease and other diseases of )
#   - Z82.5 (Z82.5
# Family history of asthma and other chronic lower respiratory )
#   - Z82.6 (Z82.6
# Family history of arthritis and other diseases of the )
#   - Z82.62 (Z82.62
# Family history of osteoporosis )
#   - Z82.69 (Z82.69
# Family history of other diseases of the musculoskeletal )
#   - Z82.7 (Z82.7
# Family history of congenital malformations, deformations and )
#   - Z82.79 (Z82.79
# Family history of other congenital malformations, )
#   - Z82.8 (Z82.8
# Family history of other disabilities and chronic diseases )
# Z86 () ->
#   - Z86.0 (Z86.0
# Personal history of in-situ and benign neoplasms and )
#   - Z86.00 (Z86.00
# Personal history of in-situ neoplasm )
#   - Z86.01 (Z86.01
# Personal history of benign neoplasm )
#   - Z86.03 (Z86.03
# Personal history of neoplasm of uncertain behavior )
#   - Z86.1 (Z86.1
# Personal history of infectious and parasitic diseases )
#   - Z86.11 (Z86.11
# Personal history of tuberculosis )
#   - Z86.12 (Z86.12
# Personal history of poliomyelitis )
#   - Z86.13 (Z86.13
# Personal history of malaria )
#   - Z86.19 (Z86.19
# Personal history of other infectious and parasitic )
#   - Z86.2 (Z86.2
# Personal history of diseases of the blood and blood-forming )
#   - Z86.39 (Z86.39
# Personal history of other endocrine, nutritional and )
#   - Z86.6 (Z86.6
# Personal history of diseases of the nervous system and sense )
#   - Z86.69 (Z86.69
# Personal history of other diseases of the nervous system and )
#   - Z86.7 (Z86.7
# Personal history of diseases of the circulatory system )
#   - Z86.71 (Z86.71
# Personal history of venous thrombosis and embolism )
#   - Z86.72 (Z86.72
# Personal history of thrombophlebitis )
#   - Z86.73 (Z86.73
# Personal history of transient ischemic attack (TIA), and )
#   - Z86.74 (Z86.74
# Personal history of sudden cardiac arrest )
#   - Z86.79 (Z86.79
# Personal history of other diseases of the circulatory )

# %%
# %%
# Save and Load Graph Example
print("\n--- Saving Graph ---")
icd_graph.save_to_file('icd_graph.pkl')

# To load the graph later:
loaded_graph = Graph.load_from_file('icd_graph.pkl')
print(f"Loaded graph has {len(loaded_graph.adjacency_list)} nodes")
# Out:
# --- Saving Graph ---
# Graph saved to icd_graph.pkl
# Graph loaded from icd_graph.pkl
# Loaded graph has 23842 nodes
